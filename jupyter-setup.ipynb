# %% [markdown]
# # 🚀 NexusLang v2 - RunPod Setup via Jupyter
#
# Upload nexuslang-v2-deploy.zip first, then run these cells in order!

# %% [markdown]
# ## Step 1: Extract Uploaded Files
#
# Make sure you've uploaded `nexuslang-v2-deploy.zip` to `/workspace` first!

# %%
# !cd /workspace && unzip -o nexuslang-v2-deploy.zip -d nexuslang-v2
# !cd /workspace/nexuslang-v2 && chmod +x *.sh
print("✅ Files extracted to /workspace/nexuslang-v2")

# %% [markdown]
# ## Step 2: Install Docker & Docker Compose
